# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/bb/Logo_WAT.svg" width="150">
#
# # Laboratorium 2 — Analiza danych w Jupyter Notebook
#
# ## Cel ćwiczenia
# Celem zajęć jest zapoznanie studentów z pracą w środowisku Jupyter Notebook oraz wykorzystanie bibliotek **NumPy**, **Pandas** i **Matplotlib** do analizy i wizualizacji danych.
#
# ---
#
# ### Instrukcja:
# 1. Nie edytuj pól oznaczonych jako `Instrukcja` (są zablokowane).
# 2. Uzupełnij wszystkie komórki oznaczone `Do uzupełnienia`.
# 3. Po wykonaniu ćwiczenia wyeksportuj notatnik do **PDF** i prześlij prowadzącemu.

# %%
# Instrukcja: Uruchom tę komórkę, aby załadować potrzebne biblioteki.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("Biblioteki zaimportowane pomyślnie ✅")

# %% [markdown]
# ## Zadanie
#
# **RESZTA**
